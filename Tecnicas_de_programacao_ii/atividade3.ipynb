# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.set_theme(style="white", palette='deep')

# %% [markdown]
# #### Questão 1

# %% [markdown]
# Qual o valor médio da gorjeta (*tip*) de acordo com o dia da semana (*day*)?

# %%
sns.barplot(data=tips, 
            x='day', 
            y='tip', 
            estimator='mean', 
            errorbar=None)

# Aesthetic
plt.title('Valor médio da gorjeta por dia da semana')
plt.xlabel('Dia da semana')
plt.ylabel('Valor médio da gorjeta')

# Show
plt.show()

# %% [markdown]
# #### Questão 2

# %% [markdown]
# Qual a soma das gorjetas (*tip*) por turno do dia (*time*), observando os fumantes e não fumantes (*smoker*)?

# %%
sns.barplot(data=tips, 
            x='time', 
            y='tip', 
            hue='smoker', 
            estimator='sum', 
            errorbar=None)

# Aesthetic
plt.title('Valor da gorjeta por turno')
plt.xlabel('Turno do dia')
plt.ylabel('Valor da soma das gorjeta')
plt.legend(title='Fumantes')

# Show
plt.show()

# %% [markdown]
# #### Questão 3

# %% [markdown]
# Verique a distribuição de gorjetas (*tip*) por dia (*day*) e turno (*time*). Há algum dia e turno com maior presença de outliers?

# %%
sns.boxplot(data=tips, 
            y='tip', 
            x='day', 
            hue='time')

# Aesthetic
plt.title('Distribuição das gorjetas por dia e turno')
plt.xlabel('Dia da semana')
plt.ylabel('Gorjetas')
plt.legend(title='Turno')

# Show
plt.show()

# %% [markdown]
# ``Aos sábados no jantar há maior presença de outliers``

# %% [markdown]
# #### Questão 4

# %% [markdown]
# Qual a relação do valor total da conta com o valor da gorjeta?

# %%
sns.scatterplot(data=tips,
                x='total_bill',
                y='tip')

# Aesthetic
plt.title('Valor da gorjeta x Valor total da conta')
plt.xlabel('Valor da total da conta')
plt.ylabel('Valor da gorjeta')
plt.grid()

# Show
plt.show()

# %% [markdown]
# #### Questão 5

# %% [markdown]
# Qual público dá maior quantidade de gorjetas:
#
#
# 1.   Homens ou mulheres?
# 2.   Fumantes ou não fumantes?

# %%
sns.barplot(data=tips, 
            x='sex', 
            y='tip', 
            hue='smoker', 
            estimator='mean', 
            errorbar=None)

# Aesthetic
plt.title('Quantidade de gorjetas')
plt.xlabel('Sexo')
plt.ylabel('Gorjeta')
plt.legend(title='Fumantes', loc='upper left', bbox_to_anchor=(1, 1))

# Show
plt.show()
